# %%
print ("hola mundo")
# Out:
# hola mundo

# %%
nombre = "Diego Rojas"
edad = 26
ciudad = "Asunción"

print (nombre, edad, ciudad)

# ta bien
# Out:
# Diego Rojas 26 Asunción

# %%
#Suma
cantidad_de_manzanas = 6
cantidad_de_naranjas = 7
cantidad_de_frutas = cantidad_de_manzanas + cantidad_de_naranjas
print ("La cantidad de frutas es", cantidad_de_frutas)

#Resta
frutas_vendidas = 9
frutas_restantes = cantidad_de_frutas - frutas_vendidas
print ("Las frutas que sobran son", frutas_restantes)
# Out:
# La cantidad de frutas es 13
# Las frutas que sobran son 4

# %%
nombre = "Juan"
apellido = "Cristaldo"
print(f"Hola me llamo {nombre} {apellido}. Mucho gusto")
# Out:
# Hola me llamo Juan Cristaldo. Mucho gusto

# %%
numero1 = int(input("elige el primer numero"))
print("el primer numero es", numero1)
numero2 = int(input("elige el segundo numero"))
print("el segundo numero es", numero2)
print(f"La suma de los numeros {numero1} y {numero2} es = ", numero1+numero2)
# Out:
# el primer numero es 3
# el segundo numero es 4
# La suma de los numeros 3 y 4 es =  7

# %%
def prepararvorivori():
    print("ya esta el vori vori?")
    print("falta poco")

prepararvorivori()
prepararvorivori()
prepararvorivori()
# Out:
# ya esta el vori vori?
# falta poco
# ya esta el vori vori?
# falta poco
# ya esta el vori vori?
# falta poco

# %%
def mostrar_producto(elemento, primera_caracteristica, segunda_caracteristica, tercera_caracteristica):
    print(f"El elemento a comprar es {elemento}, y cuenta con las siguientes caracteristicas: {primera_caracteristica}, {segunda_caracteristica}, {tercera_caracteristica}")

def producto_a_comprar():
    elemento = input("Ingrese el elemento a comprar: ")
    primera_caracteristica = input("Ingrese una caracteristica del elemento a comprar: ")
    segunda_caracteristica = input("Ingrese otra caracteristica del elemento a comprar: ")
    tercera_caracteristica = input("Ingrese una ultima caracteristica del elemento a comprar: ")

    mostrar_producto(elemento, primera_caracteristica, segunda_caracteristica, tercera_caracteristica)

producto_a_comprar()

# %%
def mostrar_ropa(ropa,tamaño,color):
    print("El tipo de ropa que queres es {ropa}, del tamaño de {tamaño} y de color {color}")


def comprar_ropa():
    ropa = input(f"Ingrese el tipo de ropa a comprar: ")
    tamaño = input(f"Ingrese el tamaño que quiere: ")
    color = input(f"Ingrese el color: ")

    mostrar_ropa(ropa, tamaño, color)

comprar_ropa()
# Out:
# El tipo de ropa que queres es {ropa}, del tamaño de {tamaño} y de color {color}
